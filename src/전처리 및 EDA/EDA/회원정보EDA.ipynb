# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# 경고 메시지가 뜨지 않게 설정
import warnings 
warnings.filterwarnings('ignore')

# 그래프 설정
# sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# matplotlib 설정
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import PercentFormatter

def comma_formatter(x, pos):
    return f'{int(x):,}'

# 인코딩
from sklearn.preprocessing import LabelEncoder

# 검정
from scipy import stats

# %% [markdown]
# - 데이터 불러오기

# %%
df = pd.read_parquet('2018_회원정보.parquet')

# %%
check = pd.read_csv('병합_selected_features.csv')

# %%
df[list(check.columns)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df[list(check.columns)]
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['이용금액_오프라인_R3M', '이용금액대_ord', '정상청구원금_B2M', '연속유실적개월수_기본_24M_카드', '미이용_CA', '정상청구원금_B0M', '최대이용금액_체크_R12M', '최대이용금액_CA_R12M', '미이용_할부', '이용건수_신용_R12M', '이용금액_오프라인_B0M', '이용금액_체크_R12M', '이용금액_체크_R3M', '최대이용금액_일시불_R12M', '이용금액_체크_R6M', '월상환론한도금액', '이용금액_일시불_R12M', '이용건수_CA_R12M', '이용개월수_신용_R12M', '이용건수_오프라인_R6M', '강제한도감액금액_R12M', '평잔_카드론_3M', '카드이용한도금액_B2M', '일시상환론한도금액', '경과일수_CA', '이용개월수_신용_R6M', '이용금액_CA_R6M', '평잔_일시불_6M', '최대이용금액_할부_무이자_R12M', '변동률_RVCA평잔', '증감율_이용금액_일시불_분기', '이용건수_일시불_B0M', '카드이용한도금액_B1M', '이용금액_CA_R12M', '할부금액_6M_R12M', '이용개월수_CA_R3M', '이용개월수_체크_R12M', '한도증액횟수_R12M', '이용금액_오프라인_R6M', '평잔_카드론_6M', '이용건수_신판_B0M', '최대이용금액_할부_R12M', 'OS구분_Android', '연체입금원금_B2M', '이용개월수_CA_R12M', '연체입금원금_B0M', '이용금액_할부_무이자_R12M', '이용개월수_CA_R6M', '한도증액후경과월', '강제한도감액횟수_R12M', '이용금액_할부_R12M', 'CA이자율_할인전', '_2순위업종_이용금액', '이용메뉴건수_ARS_B0M', '이용후경과월_신판', '증감율_이용금액_신판_분기', '이용건수_신판_R12M', '이용가맹점수', '이용개월수_일시불_R12M', '이용금액_체크_B0M', '할인금액_청구서_R3M', '카드이용한도금액', '이용건수_선결제_R6M', '연체입금원금_B5M', '이용후경과월_신용', '경과일수_카드론', '이용건수_오프라인_R3M', '이용건수_일시불_R3M', '연속무실적개월수_기본_24M_카드', '이용건수_일시불_R6M', '정상청구원금_B5M', '이용개월수_체크_R6M', '증감율_이용금액_신용_분기', '이용개월수_체크_R3M', '미이용_일시불', '상담건수_B0M', '이용건수_신판_R6M', '쇼핑_슈퍼마켓_이용금액', '이용건수_체크_R3M', '이용금액_일시불_R6M', '잔액_카드론_B5M', '경과일수_일시불', '불만제기후경과월_R12M', '이용후경과월_체크', '이용건수_할부_무이자_R12M', '_2순위여유업종_공원', '할부금액_유이자_6M_R12M', '이용건수_체크_R12M', '이용건수_오프라인_B0M', '이용건수_신용_B0M', '이용건수_신판_R3M', '청구금액_R3M', '최종카드론_대출이율', '포인트_적립포인트_R3M', '이용건수_일시불_R12M', '_2순위쇼핑업종_이용금액', '컨택건수_이용유도_EM_B0M', '자발한도감액금액_R12M', '이용금액_온라인_R6M', '이용개월수_일시불_R6M', '이용개월수_신판_R12M', '잔액_카드론_B4M', '포인트_포인트_월적립_R3M', '컨택건수_채권_B0M', '이용개월수_신용_R3M', '캠페인접촉일수_R12M_num', '이용개월수_결제일_R6M', '변동률_일시불평잔', '마일_적립포인트_R12M', '잔액_카드론_B2M', '_1순위교통업종_정비', '_3순위업종_이용금액', '평잔_CA_3M', '이용금액_일시불_R3M', '최종카드론이용경과월', '경과일수_할부', '컨택건수_이용유도_EM_R6M', '경과일수_신판', '할인금액_B0M', '이용개월수_오프라인_R6M', '컨택건수_이용유도_인터넷_B0M', '이용금액_일시불_B0M', '강제한도감액후경과월', '여유_공원이용금액', '당사멤버쉽_방문횟수_B0M', 'rv최초시작후경과일', '한도증액금액_R12M', '당사멤버쉽_방문횟수_R6M', 'RV_최대잔액_R3M', '월중평잔_RV일시불', '잔액_신판평균한도소진율_r6m', '_1순위교통업종_이용금액', '이용개월수_전체_R3M', 'RV일시불이자율_할인전', '할부금액_무이자_3M_R12M', 'RP후경과월_전기', '이용금액_카드론_R12M', '이용건수_체크_R6M', 'RV_평균잔액_R12M', '이용개월수_할부_유이자_R6M', '_3순위쇼핑업종_이용금액', '잔액_할부_유이자_B0M', '잔액_현금서비스_B2M', 'RV_최대잔액_R12M'] not in index"

# %%
drop_list = ['이용금액_오프라인_R3M', '이용금액대_ord', '정상청구원금_B2M', '연속유실적개월수_기본_24M_카드', '미이용_CA', '정상청구원금_B0M',
             '최대이용금액_체크_R12M', '최대이용금액_CA_R12M', '미이용_할부', '이용건수_신용_R12M', '이용금액_오프라인_B0M', '이용금액_체크_R12M',
             '이용금액_체크_R3M', '최대이용금액_일시불_R12M', '이용금액_체크_R6M', '월상환론한도금액', '이용금액_일시불_R12M', '이용건수_CA_R12M',
             '이용개월수_신용_R12M', '이용건수_오프라인_R6M', '강제한도감액금액_R12M', '평잔_카드론_3M', '카드이용한도금액_B2M', '일시상환론한도금액',
             '경과일수_CA', '이용개월수_신용_R6M', '이용금액_CA_R6M', '평잔_일시불_6M', '최대이용금액_할부_무이자_R12M', '변동률_RVCA평잔',
             '증감율_이용금액_일시불_분기', '이용건수_일시불_B0M', '카드이용한도금액_B1M', '이용금액_CA_R12M', '할부금액_6M_R12M', '이용개월수_CA_R3M',
             '이용개월수_체크_R12M', '한도증액횟수_R12M', '이용금액_오프라인_R6M', '평잔_카드론_6M', '이용건수_신판_B0M', '최대이용금액_할부_R12M',
             'OS구분_Android', '연체입금원금_B2M', '이용개월수_CA_R12M', '연체입금원금_B0M', '이용금액_할부_무이자_R12M', '이용개월수_CA_R6M',
             '한도증액후경과월', '강제한도감액횟수_R12M', '이용금액_할부_R12M', 'CA이자율_할인전', '_2순위업종_이용금액', '이용메뉴건수_ARS_B0M',
             '이용후경과월_신판', '증감율_이용금액_신판_분기', '이용건수_신판_R12M', '이용가맹점수', '이용개월수_일시불_R12M', '이용금액_체크_B0M',
             '할인금액_청구서_R3M', '카드이용한도금액', '이용건수_선결제_R6M', '연체입금원금_B5M', '이용후경과월_신용', '경과일수_카드론', '이용건수_오프라인_R3M',
             '이용건수_일시불_R3M', '연속무실적개월수_기본_24M_카드', '이용건수_일시불_R6M', '정상청구원금_B5M', '이용개월수_체크_R6M',
             '증감율_이용금액_신용_분기', '이용개월수_체크_R3M', '미이용_일시불', '상담건수_B0M', '이용건수_신판_R6M', '쇼핑_슈퍼마켓_이용금액',
             '이용건수_체크_R3M', '이용금액_일시불_R6M', '잔액_카드론_B5M', '경과일수_일시불', '불만제기후경과월_R12M', '이용후경과월_체크',
             '이용건수_할부_무이자_R12M', '_2순위여유업종_공원', '할부금액_유이자_6M_R12M', '이용건수_체크_R12M', '이용건수_오프라인_B0M', '이용건수_신용_B0M',
             '이용건수_신판_R3M', '청구금액_R3M', '최종카드론_대출이율', '포인트_적립포인트_R3M', '이용건수_일시불_R12M', '_2순위쇼핑업종_이용금액',
             '컨택건수_이용유도_EM_B0M', '자발한도감액금액_R12M', '이용금액_온라인_R6M', '이용개월수_일시불_R6M', '이용개월수_신판_R12M', '잔액_카드론_B4M',
             '포인트_포인트_월적립_R3M', '컨택건수_채권_B0M', '이용개월수_신용_R3M', '캠페인접촉일수_R12M_num', '이용개월수_결제일_R6M', '변동률_일시불평잔',
             '마일_적립포인트_R12M', '잔액_카드론_B2M', '_1순위교통업종_정비', '_3순위업종_이용금액', '평잔_CA_3M', '이용금액_일시불_R3M',
             '최종카드론이용경과월', '경과일수_할부', '컨택건수_이용유도_EM_R6M', '경과일수_신판', '할인금액_B0M', '이용개월수_오프라인_R6M',
             '컨택건수_이용유도_인터넷_B0M', '이용금액_일시불_B0M', '강제한도감액후경과월', '여유_공원이용금액', '당사멤버쉽_방문횟수_B0M', 'rv최초시작후경과일',
             '한도증액금액_R12M', '당사멤버쉽_방문횟수_R6M', 'RV_최대잔액_R3M', '월중평잔_RV일시불', '잔액_신판평균한도소진율_r6m', '_1순위교통업종_이용금액',
             '이용개월수_전체_R3M', 'RV일시불이자율_할인전', '할부금액_무이자_3M_R12M', 'RP후경과월_전기', '이용금액_카드론_R12M', '이용건수_체크_R6M',
             'RV_평균잔액_R12M', '이용개월수_할부_유이자_R6M', '_3순위쇼핑업종_이용금액', '잔액_할부_유이자_B0M', '잔액_현금서비스_B2M', 'RV_최대잔액_R12M']

# %%
df = df[list(check.drop(drop_list, axis = 1).columns)]

# %%
train = df.loc[df['Segment'].notna()]

# %%
df = train.copy()

# %%
# Segment 인코딩
le = LabelEncoder()
target_ec = le.fit_transform(df['Segment'])

# %%
for idx, val in enumerate(df.columns) :
    print(f'{idx} : {val}')
# Out:
# 0 : ID
# 1 : Segment
# 2 : 이용금액_R3M_신용체크
# 3 : 입회일자_신용
# 4 : 입회경과개월수_신용
# 5 : 소지카드수_유효_신용
# 6 : 수신거부여부_메일
# 7 : 소지카드수_이용가능_신용
# 8 : _1순위카드이용건수
# 9 : 유효카드수_신용체크
# 10 : 회원여부_이용가능_CA
# 11 : 유효카드수_신용
# 12 : 이용가능카드수_신용
# 13 : 보유여부_해외겸용_본인
# 14 : 탈회횟수_발급1년이내
# 15 : 최종카드발급경과월
# 16 : 이용금액_R3M_체크
# 17 : 유효카드수_신용_가족
# 18 : 회원여부_이용가능
# 19 : 이용가능여부_해외겸용_신용_본인
# 20 : 수신거부여부_DM
# 21 : 마케팅동의여부
# 22 : 이용금액_R3M_신용
# 23 : 이용가능카드수_체크
# 24 : 이용가능여부_해외겸용_본인

# %%
custom_palette = ['#0048FF', '#0037C3', '#2E69FF', '#0033B4', '#001F6F']

# %% [markdown]
# ### 고객의 분류하는 기준이 되는 변수 찾기

# %% [markdown]
# #### 1.회원여부_이용가능
# - 분실/연체/한도 소진 등의 이유로 블랙리스트로 등재되지 않은 회원인지 여부를 나타내는 데이터

# %%
# 블랙리스트 분포 확인
df['회원여부_이용가능'].value_counts(normalize = True)
# Out:
# 회원여부_이용가능
# 1    0.952575
# 0    0.047425
# Name: proportion, dtype: float64

# %%
# Segment별 블랙리스트 등재 고객 비율 확인
df.loc[df['회원여부_이용가능'] == 0, 'Segment'].value_counts(normalize = True)
# Out:
# Segment
# E    0.959480
# D    0.032165
# C    0.008355
# Name: proportion, dtype: float64

# %% [markdown]
# - Segment의 분포 비율은 불균형이 심하기 때문에 의미가 없다.

# %%
df.loc[df['회원여부_이용가능'] == 0, 'Segment'].value_counts() / df['Segment'].value_counts()
# Out:
# Segment
# A         NaN
# B         NaN
# C    0.007454
# D    0.010483
# E    0.056818
# Name: count, dtype: float64

# %%
# 비율 계산: 각 Segment별 블랙리스트 비율

a1 = (
    df.loc[df['회원여부_이용가능'] == 0, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# bar plot
plt.figure(figsize = (4, 4))
a1.plot(kind='bar', color=custom_palette[:len(a1)])
plt.title('Segment별 블랙리스트 비율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 0.1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.xticks(rotation=0)

plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# - 블랙리스트로 등재된 회원은 대부분 E 유형의 고객이다.
# - A, B의 경우 한 명도 블랙리스트로 등재되지 않았다.

# %% [markdown]
# #### 2.회원여부_이용가능_CA
# - 신용카드 현금 서비스 이용이 가능한 고객인지 여부를 확인하는 데이터

# %%
df['회원여부_이용가능_CA'].value_counts()
# Out:
# 회원여부_이용가능_CA
# 1    2112243
# 0     287757
# Name: count, dtype: int64

# %%
# Segment별 현금 서비스 이용 불가능한 고객 비율
(df.loc[df['회원여부_이용가능_CA'] == 0, 'Segment'].value_counts() / df['Segment'].value_counts()).sort_values(ascending = False)
# Out:
# Segment
# E    0.134860
# D    0.061771
# C    0.054534
# B    0.041667
# A    0.012346
# Name: count, dtype: float64

# %% [markdown]
# - Segment 별 현금 서비스 이용이 불가능한 고객의 비율이 E에서 A로 갈수록 낮아지는 것을 볼 수 있다.

# %%
# 비율 계산: 각 Segment별 블랙리스트 비율

a1 = (
    df.loc[df['회원여부_이용가능_CA'] == 0, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# bar plot
plt.figure(figsize = (4, 4))
a1.plot(kind='bar', color=custom_palette[:len(a1)])
plt.title('Segment별 현금 서비스 이용이 불가능한 회원 비율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 0.2)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.xticks(rotation=0)

plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %%
df[['회원여부_이용가능', '회원여부_이용가능_CA']].corr()
# Out:
#               회원여부_이용가능  회원여부_이용가능_CA
# 회원여부_이용가능       1.00000       0.59048
# 회원여부_이용가능_CA    0.59048       1.00000

# %% [markdown]
# - Segment별 현금서비스 이용이 불가능한 회원의 비율 또한 A로 갈수록 낮아진다.

# %% [markdown]
# #### 3.소지카드수_유효_신용

# %%
df['소지카드수_유효_신용'].value_counts()
# Out:
# 소지카드수_유효_신용
# 1    1845949
# 2     391523
# 3     120560
# 0      41882
# 4         86
# Name: count, dtype: int64

# %% [markdown]
# #### 4.소지카드수_이용가능_신용

# %%
df['소지카드수_이용가능_신용'].value_counts()
# Out:
# 소지카드수_이용가능_신용
# 1    1723263
# 2     370561
# 0     205225
# 3     100951
# Name: count, dtype: int64

# %%
sum(df['소지카드수_유효_신용'] == df['소지카드수_이용가능_신용']) / df.shape[0]
# Out:
# 0.9097341666666666

# %%
df[['소지카드수_이용가능_신용', '소지카드수_유효_신용']].corr()
# Out:
#                소지카드수_이용가능_신용  소지카드수_유효_신용
# 소지카드수_이용가능_신용       1.000000     0.872904
# 소지카드수_유효_신용         0.872904     1.000000

# %% [markdown]
# - 두 변수는 약 91% 정도가 일치한다.
# - Pearson 상관계수로 두 변수 간의 관계를 확인한 결과 강한 상관관계를 가진다는 것을 알 수 있다.
# - Segment와의 관계 확인 후 둘중 하나는 제거하도록 한다.

# %%
# Segment
target = df['Segment']

# segment를 원-핫 인코딩
segment_dummies = pd.get_dummies(target, prefix='segment')

card_df = pd.DataFrame({
    '소지카드수_유효_신용' : df['소지카드수_유효_신용'],
    '소지카드수_이용가능_신용' : df['소지카드수_이용가능_신용']
})

corr_df = pd.concat([card_df, segment_dummies], axis = 1)

# 전체 상관계수 구하기 (피어슨 방식이 기본)
corr_matrix = corr_df.corr()

# segment_dummies 행 vs numeric_cols 열만 추출
segment_corr = corr_matrix.loc[segment_dummies.columns, card_df.columns]

# 히트맵 시각화
plt.figure(figsize=(4, 7))
sns.heatmap(segment_corr.T, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, vmin = -1, vmax = 1)
plt.title('Pearson Correlation: Segment vs 한도 정보 그룹', pad = 20)
plt.xlabel('한도 정보 그룹 Variables')
plt.ylabel('Segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# - 소지카드수_유효_신용이 더 관계가 높기 때문에 해당 칼럼을 확인한다.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# 탈퇴율 계산
a1 = (
    df.loc[df['탈회횟수_발급1년이내'] == 1, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# 블루 계열 색상 (E, D, C, B, A 순서에 맞게 설정)
custom_colors = ['#001F66', '#0033CC', '#3399FF', '#004CFF', '#0066FF']

# 단일 bar plot
plt.figure(figsize=(4, 4))
a1.plot(kind='bar', color=custom_colors)

plt.title('세그먼트별 탈퇴율(1년이내)', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 0.1)

plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))  # % 표시
plt.xticks(rotation=0)
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 사용자 지정 블루 계열 색상
custom_palette = ['#0066FF', '#004CFF', '#3399FF', '#0033CC', '#001F66']  # A ~ E 순서

# Boxplot 생성
plt.figure(figsize=(10, 5))
plt.title('Segment별 유효한 신용카드 소지카드수 Box Plot')
sns.boxplot(x='Segment', y='소지카드수_유효_신용', data=df, palette=custom_palette)
plt.legend()
plt.xlabel('Segment')
plt.ylabel('소지카드수_유효_신용')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# 사용자 지정 블루 계열 색상
custom_palette = ['#0066FF', '#004CFF', '#3399FF', '#0033CC', '#001F66']  # A ~ E 순서
segments = ['A', 'B', 'C', 'D', 'E']

# Boxplot 생성
plt.figure(figsize=(10, 5))
plt.title('Segment별 유효한 신용카드 소지카드수 Box Plot')

# boxplot 그리기
sns.boxplot(x='Segment', y='소지카드수_유효_신용', data=df, palette=custom_palette)

# 범례 수동 생성 (그래프 외부 우측으로)
legend_patches = [Patch(facecolor=custom_palette[i], label=f'Segment {seg}') for i, seg in enumerate(segments)]
plt.legend(handles=legend_patches, title='Segment', loc='center left', bbox_to_anchor=(1, 0.5))

# 라벨 설정
plt.xlabel('Segment')
plt.ylabel('소지카드수_유효_신용')

# 레이아웃 조정 (그래프 + 범례 공간 확보)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Segment E 고객은 신용카드를 거의 한장만 보유한다.
# - 반대로 Segment C와 A는  다양하게 2 ~ 3장 이상 보유 -> 활동성이 높은 유형일 가능성이 있다.

# %% [markdown]
# #### 5.입회일자_신용
# - 카드 회원이 된 일자
# - 입회일자에서 기준년월까지의 개월 수를 나타내는 입회경과개월수_신용 칼럼이 있기 때문에 해당 칼럼은 사용하지 않는다.

# %% [markdown]
# #### 6. 입회경과개월수_신용

# %%
df['입회경과개월수_신용'].value_counts()
# Out:
# 입회경과개월수_신용
# 6      119886
# 5       64069
# 4       59968
# 3       55969
# 2       52023
#         ...
# 334         1
# 329         1
# 335         1
# 330         1
# 336         1
# Name: count, Length: 335, dtype: int64

# %%
print(df['입회경과개월수_신용'].min())
print(df['입회경과개월수_신용'].max())
# Out:
# 2
# 337

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 세그먼트 리스트
segments = ['A', 'B', 'C', 'D', 'E']
custom_palette = ['#0048FF', '#0037C3', '#2E69FF', '#0033B4', '#001F6F']

# subplot 생성 (2행 3열)
fig, axs = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Segment별 입회경과개월수_신용 분포', fontsize=16)

# 세그먼트별 히스토그램 생성
for i, segment in enumerate(segments):
    row, col = divmod(i, 3)
    data = df[df['Segment'] == segment]
    sns.histplot(data=data, x='입회경과개월수_신용', bins=10, kde=True, ax=axs[row, col], 
                 color=custom_palette[i])
    axs[row, col].set_title(f'Segment {segment}')
    axs[row, col].set_xlabel('입회경과개월수_신용')
    axs[row, col].set_ylabel('Count')

# 마지막 subplot (2, 3 중 빈칸) 제거
axs[1, 2].axis('off')

# 레이아웃 정리
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 세그먼트 그룹 정의
segment_groups = {
    'Segment A+B': ['A', 'B'],    
    'Segment D+C': ['D', 'C'],
    'Segment E': ['E']
}

custom_palette = ['#0048FF', '#0037C3', '#2E69FF']  # 그룹 수에 맞춰 색상 선택

# subplot 생성 (1행 3열)
fig, axs = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Segment 그룹별 입회경과개월수_신용 분포', fontsize=16)

# 그룹별 그래프 생성
for i, (group_name, seg_list) in enumerate(segment_groups.items()):
    data = df[df['Segment'].isin(seg_list)]
    sns.histplot(data=data, x='입회경과개월수_신용', bins=20, kde=True, ax=axs[i], color=custom_palette[i], hue = 'Segment')
    axs[i].set_title(group_name)
    axs[i].set_xlabel('입회경과개월수_신용')
    axs[i].set_ylabel('Count')
    axs[i].grid(axis='y', linestyle='--', alpha=0.7)  # 가로선 격자 추가

# 레이아웃 정리
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 세그먼트 리스트
segments = ['A', 'B', 'C', 'D', 'E']

# subplot 설정 (2행 3열)
fig, axs = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Segment별 입회경과개월수_신용 분포', fontsize=16)

# 세그먼트별 히스토그램 그리기
for i, segment in enumerate(segments):
    row, col = divmod(i, 3)
    data = df[df['Segment'] == segment]
    sns.histplot(data=data, x='입회경과개월수_신용', bins=10, kde=True, ax=axs[row, col])
    axs[row, col].set_title(f'Segment {segment}')
    axs[row, col].set_xlabel('입회경과개월수_신용')
    axs[row, col].set_ylabel('Count')

# 마지막 subplot (2,3 중 빈칸) 제거
axs[1, 2].axis('off')

# 레이아웃 정리
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# - Segment E의 경우 25개월 이내 신규 가입한 고객의 비중이 매우 높다.
# - C, D의 경우 주로 50 ~ 75개월 사이에 주로 분포를 이룬다.
# - Segment B의 경우 100개월 경과 지점에 가장 큰 도수 값을 기록하지만 전체적으로 완만하고 꼬리가 두껍게 분포되어 있다.
# - A 분포는 회원 가입일이 250개월의 장기 가입 회원이 분포를 이루고 있다.
#
# - 결론 : 회원가입 경과(개월수)가 길수록 Segment A에 가까워 진다.

# %% [markdown]
# #### 7. 수신거부여부_DM
# - 카드사에서 보낸 DM의 수신을 거부 여부를 보여주는 데이터.

# %%
df['수신거부여부_DM'].value_counts(normalize = True)
# Out:
# 수신거부여부_DM
# 0    0.680845
# 1    0.319155
# Name: proportion, dtype: float64

# %%
df.loc[df['수신거부여부_DM'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()
# Out:
# Segment
# E    0.293920
# D    0.412287
# C    0.443358
# A    0.456790
# B    0.291667
# Name: count, dtype: float64

# %%
# 비율 계산
a1 = df.loc[df['수신거부여부_DM'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()

# 두 번째 그래프
plt.figure(figsize = (4, 4))
a1.plot(kind='bar', color=custom_palette[:len(a1)])
plt.title('세그먼트 별 DM 수신거부율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.xticks(rotation=0)

plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# - 대체로 수신거부(DM) 비율이 30 ~ 40% 정도이다.
# - 딱히 분석에 유의미한 차이는 없는 것으로 보인다.
# - 수신거부(DM)율 자체는 A 고객이 가장 큰 것으로 보인다.

# %% [markdown]
# ### 8.수신거부여부_메일
# - 카드사에서 보내는 메일의 수신을 거부 여부를 나타내는 데이터

# %%
# 수신거부여부_메일의 분포를 확인한다.
df['수신거부여부_메일'].value_counts(normalize = True)
# Out:
# 수신거부여부_메일
# 0    0.674913
# 1    0.325087
# Name: proportion, dtype: float64

# %%
df.loc[df['수신거부여부_메일'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()
# Out:
# Segment
# E    0.299199
# D    0.420997
# C    0.451540
# A    0.462963
# B    0.291667
# Name: count, dtype: float64

# %%
# 비율 계산
a1 = df.loc[df['수신거부여부_메일'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()

# 두 번째 그래프
plt.figure(figsize = (4, 4))
a1.plot(kind='bar', color=custom_palette[:len(a1)])
plt.title('세그먼트별 메일 수신거부율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.xticks(rotation=0)

plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# - 수신거부여부_메일 칼럼과 수신거부여부_DM 칼럼의 분포가 이상하리만치 일치한다.
# - 두 분포의 일치율을 확인해 본다.

# %%
sum(df['수신거부여부_메일'] == df['수신거부여부_DM']) / df.shape[0]
# Out:
# 0.9894875

# %%
df[['수신거부여부_메일', '수신거부여부_DM']].corr()
# Out:
#            수신거부여부_메일  수신거부여부_DM
# 수신거부여부_메일   1.000000   0.976019
# 수신거부여부_DM   0.976019   1.000000

# %% [markdown]
# - 두 분포가 99%일치하는 칼럼이므로 다중공선성 문제를 가지고 있다.
# - 둘 변수 중 Segment와의 상관계수가 낮은 하나의 칼럼을 제거한다.

# %%
# Segment
target = df['Segment']

# segment를 원-핫 인코딩
segment_dummies = pd.get_dummies(target, prefix='segment')

card_df = pd.DataFrame({
    '수신거부여부_DM' : df['수신거부여부_DM'],
    '수신거부여부_메일' : df['수신거부여부_메일']
})

corr_df = pd.concat([card_df, segment_dummies], axis = 1)

# 전체 상관계수 구하기 (피어슨 방식이 기본)
corr_matrix = corr_df.corr()

# segment_dummies 행 vs numeric_cols 열만 추출
segment_corr = corr_matrix.loc[segment_dummies.columns, card_df.columns]

# 히트맵 시각화
plt.figure(figsize=(5, 6))
sns.heatmap(segment_corr.T, annot=True, cmap='coolwarm', fmt=".3f", linewidths=0.5, vmin = -1, vmax = 1)
plt.title('Pearson Correlation: Segment vs 한도 정보 그룹', pad = 20)
plt.xlabel('한도 정보 그룹 Variables')
plt.ylabel('Segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# - 두 변수는 Segment와의 상관계수가 소수점 2자리 까지 동일할 만큼 일치율이 높다.
# - 3자리수 까지 확인 결과 수신거부여부_메일 칼럼이 미세하게 상관 계수가 높은 것으로 보인다.

# %% [markdown]
# #### 9.탈회횟수_발급1년이내
# - 신용카드를 발급받고 1년 이내에 탈회한 수를 나타내는 데이터

# %%
# 탈회횟수_발급1년이내 분포 확인
print(df['탈회횟수_발급1년이내'].value_counts())
print()
print(df['탈회횟수_발급1년이내'].value_counts(normalize = True))
# Out:
# 탈회횟수_발급1년이내
# 0    374676
# 1     25324
# Name: count, dtype: int64
#
# 탈회횟수_발급1년이내
# 0    0.93669
# 1    0.06331
# Name: proportion, dtype: float64

# %%
# 각 Segment별 탈회횟수를 확인한다.
df.loc[df['탈회횟수_발급1년이내'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()
# Out:
# Segment
# E    0.067069
# D    0.050406
# C    0.042464
# A    0.006173
# B    0.041667
# Name: count, dtype: float64

# %%
# 비율 계산: 각 세그먼트 내에서 메일 수신 거부 비율
a1 = (
    df.loc[df['탈회횟수_발급1년이내'] == 1, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# 단일 bar plot
plt.figure(figsize=(4, 4))
a1.plot(kind='bar')
plt.title('세그먼트별 탈회율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 0.1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))  # % 표시
plt.xticks(rotation=0)
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 탈퇴율이 E에서 A로 갈수록 낮아진다.

# %% [markdown]
# #### 10.마케팅동의여부

# %%
# 마케팅동의여부의 분포와 분포 비율 확인
print(df['마케팅동의여부'].value_counts())
print()
df['마케팅동의여부'].value_counts(normalize = True)
# Out:
# 마케팅동의여부
# 1    323568
# 0     76432
# Name: count, dtype: int64
# 마케팅동의여부
# 1    0.80892
# 0    0.19108
# Name: proportion, dtype: float64

# %%
# 각 Segment 별 마케팅을 동의율
df.loc[df['마케팅동의여부'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()
# Out:
# Segment
# E    0.818313
# D    0.777175
# C    0.754667
# A    0.753086
# B    0.875000
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# 비율 계산: 각 세그먼트 내에서 메일 수신 거부 비율
a1 = (
    df.loc[df['마케팅동의여부'] == 1, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# 단일 bar plot
plt.figure(figsize=(4, 4))
a1.plot(kind='bar')
plt.title('각 세그먼트 별 마케팅동의여부', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))  # % 표시
plt.xticks(rotation=0)
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 의미있는 차이는 없는 것 같다.

# %% [markdown]
# #### 11.유효카드수_신용체크

# %%
df['유효카드수_신용체크'].value_counts()
# Out:
# 유효카드수_신용체크
# 1    155299
# 2    112355
# 3     69400
# 4     34803
# 5     13961
# 0      7646
# 6      4769
# 7      1584
# 8       183
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 세그먼트 리스트
segments = ['A', 'B', 'C', 'D', 'E']

# subplot 설정 (2행 3열)
fig, axs = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Segment별 유효카드수_신용체크 분포', fontsize=16)

# 세그먼트별 히스토그램 그리기
for i, segment in enumerate(segments):
    row, col = divmod(i, 3)
    data = df[df['Segment'] == segment]
    sns.histplot(data=data, x='유효카드수_신용체크', bins=10, kde=True, ax=axs[row, col])
    axs[row, col].set_title(f'Segment {segment}')
    axs[row, col].set_xlabel('유효카드수_신용체크')
    axs[row, col].set_ylabel('Count')

# 마지막 subplot (2,3 중 빈칸) 제거
axs[1, 2].axis('off')

# 레이아웃 정리
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# - E Segment가 대체로 적은 카드 수에 많이 분포되어 있다.
# - 3 ~ 5개 주변에 많이 모여있다. (2개 이하인 구간에도 큰 분포를 이룬다.)
# - B분포는 4개에 집중되어 있지만 데이텅의 수가 적은 관계로 확신하기엔 부족한 것 같다.
# - C는 1개에서 5개 까지 분포를 가지지만 4개 구간에서 끊긴다.
# - E는 1개에서 2개 사이에 주로 분포를 가진다.(y축 범위가 다른 분포 보다 확연히 크기 때문에 분포가 낮아보인다.)

# %% [markdown]
# #### 12.유효카드수_신용

# %%
df['유효카드수_신용'].value_counts(normalize = True)
# Out:
# 유효카드수_신용
# 1    0.618390
# 2    0.204240
# 3    0.099275
# 4    0.043725
# 0    0.026730
# 5    0.007640
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 세그먼트 리스트
segments = ['A', 'B', 'C', 'D', 'E']

# subplot 설정 (2행 3열)
fig, axs = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Segment별 유효카드수_신용 분포', fontsize=16)

# 세그먼트별 히스토그램 그리기
for i, segment in enumerate(segments):
    row, col = divmod(i, 3)
    data = df[df['Segment'] == segment]
    sns.histplot(data=data, x='유효카드수_신용', bins=10, kde=True, ax=axs[row, col])
    axs[row, col].set_title(f'Segment {segment}')
    axs[row, col].set_xlabel('유효카드수_신용')
    axs[row, col].set_ylabel('Count')

# 마지막 subplot (2,3 중 빈칸) 제거
axs[1, 2].axis('off')

# 레이아웃 정리
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# #### _1순위카드이용건수

# %%
df.loc[df['_1순위카드이용건수'].isin([-2, -1]), '_1순위카드이용건수'] = 0
df['_1순위카드이용건수'].value_counts()
# Out:
# _1순위카드이용건수
# 0      100328
# 1       10890
# 2       10066
# 3        9371
# 4        8644
#         ...
# 218        20
# 219         9
# 220         5
# 222         2
# 221         1
# Name: count, Length: 223, dtype: int64

# %%
E_df = df.loc[df['Segment'] == 'E']
DC_df = df.loc[df['Segment'].isin(['D', 'C'])]
AB_df = df.loc[df['Segment'].isin(['A', 'B'])]

# %%
df['Segment'].value_counts()
# Out:
# Segment
# E    320342
# D     58207
# C     21265
# A       162
# B        24
# Name: count, dtype: int64

# %%
# 데이터 필터링
a1 = AB_df.loc[AB_df['_1순위카드이용건수'] != 0]
a2 = DC_df.loc[DC_df['_1순위카드이용건수'] != 0]
a3 = E_df.loc[E_df['_1순위카드이용건수'] != 0]

# 서브플롯 구성
fig, axes = plt.subplots(1, 3, figsize=(18, 4))  # 1행 3열

# Segment A & B
sns.histplot(data=a1, x='_1순위카드이용건수', bins=30, kde=True, hue='Segment', ax=axes[0])
axes[0].set_title('Segment A & B')

# Segment C & D
sns.histplot(data=a2, x='_1순위카드이용건수', bins=30, kde=True, hue='Segment', ax=axes[1])
axes[1].set_title('Segment C & D')

# Segment E
sns.histplot(data=a3, x='_1순위카드이용건수', bins=30, kde=True, ax=axes[2])
axes[2].set_title('Segment E')

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# - 대체로 A가 이용건수가 많은 것으로 확인된다.

# %% [markdown]
# #### 최종카드발급경과월

# %%
df['최종카드발급경과월'].value_counts()
# Out:
# 최종카드발급경과월
# 5     14604
# 0     13231
# 16    12634
# 17    12482
# 14    12299
#       ...
# 62       53
# 63       21
# 64       16
# 65        3
# 67        1
# Name: count, Length: 67, dtype: int64

# %%
a1 = df.loc[df['Segment'] == 'E']
sns.histplot(data = a1, x = '최종카드발급경과월', bins = 20, kde = True, hue = 'Segment')
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.show()

# %%
a1 = df.loc[df['Segment'].isin(['D', 'C'])]
sns.histplot(data = a1, x = '최종카드발급경과월', kde = True, bins = 20, hue = 'Segment')
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.show()

# %%
a1 = df.loc[df['Segment'].isin(['A', 'B'])]
sns.histplot(data = a1, x = '최종카드발급경과월', kde = True, bins = 20, hue = 'Segment')
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.show()

# %%
sns.boxplot(data = df, y = '최종카드발급경과월', hue = 'Segment')
plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)
plt.show()

# %% [markdown]
# #### 보유여부_해외겸용_본인
# - 카드 고객이 해외에서 사용 가능한 카드를 가지고 있는지 여부를 나타내는 데이터

# %%
df['보유여부_해외겸용_본인'].value_counts(normalize = True)
# Out:
# 보유여부_해외겸용_본인
# 1    0.775077
# 0    0.224922
# Name: proportion, dtype: float64

# %%
(df.loc[df['보유여부_해외겸용_본인'] == 1, 'Segment'].value_counts() / df['Segment'].value_counts()).sort_values(ascending = False)
# Out:
# Segment
# A    0.987654
# B    0.958333
# C    0.934258
# D    0.890219
# E    0.743468
# Name: count, dtype: float64

# %%
# 비율 계산: 각 세그먼트 내에서 메일 수신 거부 비율
a1 = (
    df.loc[df['보유여부_해외겸용_본인'] == 1, 'Segment'].value_counts() /
    df['Segment'].value_counts()
).sort_values(ascending=False)

# 단일 bar plot
plt.figure(figsize=(4, 4))
a1.plot(kind='bar', color=custom_palette[:len(a1)])
plt.title('세그먼트별 해외겸용 카드 보유율', pad=20)
plt.ylabel('비율')
plt.xlabel('Segment')
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))  # % 표시
plt.xticks(rotation=0)

plt.grid(True, which='major', axis='y', linestyle='-', linewidth=0.5, alpha=0.7)
plt.gca().set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
for idx, val in enumerate(df.columns) :
    print(f'{idx} : {val}')
# Out:
# 0 : ID
# 1 : Segment
# 2 : 회원여부_이용가능
# 3 : 회원여부_이용가능_CA
# 4 : 소지카드수_유효_신용
# 5 : 소지카드수_이용가능_신용
# 6 : 입회일자_신용
# 7 : 입회경과개월수_신용
# 8 : 수신거부여부_DM
# 9 : 수신거부여부_메일
# 10 : 탈회횟수_발급1년이내
# 11 : 마케팅동의여부
# 12 : 유효카드수_신용체크
# 13 : 유효카드수_신용
# 14 : 유효카드수_신용_가족
# 15 : 이용가능카드수_신용
# 16 : 이용가능카드수_체크
# 17 : 이용금액_R3M_신용체크
# 18 : 이용금액_R3M_신용
# 19 : 이용금액_R3M_체크
# 20 : _1순위카드이용건수
# 21 : 보유여부_해외겸용_본인
# 22 : 이용가능여부_해외겸용_본인
# 23 : 이용가능여부_해외겸용_신용_본인
# 24 : 최종카드발급경과월
